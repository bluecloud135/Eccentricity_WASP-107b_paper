# %%
import json

# %%
tar = 'WASP-107b'
indir = 'wasp-107b'

# %%
linear_posteriors1 = json.load(open(f'{indir}/0/Nonesigma/Linear/posteriors.json'))
pdot_posteriors1 = json.load(open(f'{indir}/0/Nonesigma/Pdot/posteriors.json'))

# %%
linear_posteriors1['judgements']['BIC'] - pdot_posteriors1['judgements']['BIC']
# Out:
# 2.3068836054407775
